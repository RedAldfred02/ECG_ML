# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# ### basic graph

# %%
x=[0,1,4,3,5]
y=[0,2,8,6,10]
plt.plot(x,y, 'r.--',label='2x')
x2=np.arange(0,4,1)
plt.plot(x2,x2**2,'b' ,label='x sq.')
plt.title('graph1',fontdict={'fontname': 'Times New Roman' }) #shorthand fmt=[colour][marker][line]
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.savefig('mygraph1.png',dpi=100)
#plt.xticks(0,1,2)
plt.show()

# %%
ecg=pd.read_csv("C:\\Users\\adity\\Downloads\\ECG_training.csv")
time=np.arange(0,120.004,0.004)
ecg
# Out:
#                                                     ECG Classification
# 0     -127,-162,-197,-229,-245,-254,-261,-265,-268,-...              N
# 1     128,157,189,226,250,257,262,265,268,269,268,26...              N
# 2     519,619,723,827,914,956,955,934,920,900,889,88...              A
# 3     -266,-316,-367,-407,-423,-423,-401,-367,-329,-...              N
# 4     21,22,24,26,28,31,32,34,34,35,35,34,34,34,35,3...              N
# ...                                                 ...            ...
# 3495  347,378,410,540,695,736,751,778,849,803,688,67...              N
# 3496  -59,-71,-87,-104,-111,-114,-117,-119,-120,-121...              N
# 3497  -60,-83,-106,-128,-145,-155,-163,-168,-173,-17...              N
# 3498  582,702,807,893,962,997,984,945,927,915,906,89...              N
# 3499  162,145,97,27,-36,-64,-90,-89,-37,61,188,324,4...              N
#
# [3500 rows x 2 columns]

# %%
pip install heartpy
# Out:
# ...
#      ---------------------------------------- 1.0/1.0 MB 10.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import heartpy as hp

# %%
ecg.iloc[1]
# Out:
# ECG               128,157,189,226,250,257,262,265,268,269,268,26...
# Classification                                                    N
# Name: 1, dtype: object

# %%
l2=(ecg['ECG'].iloc[1].split(','))
print(l2)
# Out:
# ['128', '157', '189', '226', '250', '257', '262', '265', '268', '269', '268', '266', '263', '260', '258', '257', '255', '252', '249', '246', '244', '241', '238', '235', '231', '227', '223', '219', '217', '213', '209', '205', '200', '196', '192', '190', '188', '188', '189', '191', '194', '198', '202', '206', '209', '212', '216', '219', '224', '229', '234', '237', '236', '233', '228', '222', '217', '213', '209', '206', '203', '200', '197', '195', '193', '191', '190', '189', '188', '188', '188', '188', '190', '192', '196', '199', '202', '204', '207', '209', '211', '212', '213', '214', '214', '216', '218', '220', '223', '225', '228', '230', '232', '234', '234', '234', '235', '236', '237', '239', '241', '242', '244', '246', '249', '252', '254', '255', '254', '251', '247', '241', '234', '226', '215', '198', '185', '175', '168', '164', '160', '156', '153', '149', '145', '140', '134', '128', '120', '109', '91', '78', '67', '62', '59', '55', '51', '48', '45', '43', '40', '38', '36', '35', '35
# ...

# %%
l=[]
for i in range(3500):
    l1=(ecg['ECG'].iloc[i].split(','))
    l.append(l1)

# %%
print((l1))
# Out:
# ['162', '145', '97', '27', '-36', '-64', '-90', '-89', '-37', '61', '188', '324', '457', '573', '661', '691', '701', '685', '635', '583', '534', '507', '494', '489', '485', '482', '478', '474', '471', '468', '465', '461', '456', '448', '432', '414', '390', '364', '341', '316', '290', '264', '237', '206', '145', '67', '-22', '-117', '-214', '-306', '-386', '-456', '-517', '-541', '-556', '-550', '-515', '-484', '-464', '-452', '-445', '-445', '-452', '-465', '-486', '-517', '-548', '-574', '-587', '-594', '-601', '-608', '-615', '-622', '-628', '-637', '-648', '-662', '-679', '-691', '-701', '-710', '-716', '-717', '-714', '-708', '-701', '-692', '-678', '-665', '-647', '-622', '-600', '-583', '-565', '-540', '-514', '-492', '-465', '-432', '-399', '-364', '-331', '-298', '-267', '-239', '-211', '-194', '-186', '-179', '-171', '-164', '-157', '-150', '-142', '-133', '-122', '-111', '-101', '-91', '-82', '-74', '-67', '-61', '-55', '-49', '-41', '-32', '-23', '-11', '3', '24', '39', '5
# ...

# %%
time=np.arange(0,9000)
print(time)
# Out:
# [   0    1    2 ... 8997 8998 8999]

# %%
x=np.asarray(l1[:10])
print(x)
# Out:
# ['162' '145' '97' '27' '-36' '-64' '-90' '-89' '-37' '61']

# %%
plt.plot(time[:10],x)
plt.show()

# %%
working_data, features = hp.process(l1, sample_rate=300.0, calc_freq=True)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23724\1022542280.py in <module>
# ----> 1 working_data, features = hp.process(l1, sample_rate=300.0, calc_freq=True)
#
# ~\anaconda3\lib\site-packages\heartpy\heartpy.py in process(hrdata, sample_rate, windowsize, report_time, calc_freq, freq_method, welch_wsize, freq_square, interp_clipping, clipping_scale, interp_threshold, hampel_correct, bpmmin, bpmmax, reject_segmentwise, high_precision, high_precision_fs, breathing_method, clean_rr, clean_rr_method, measures, working_data)
#     278
#     279     # check that the data has positive baseline for the moving average algorithm to work
# --> 280     bl_val = np.percentile(hrdata, 0.1)
#     281     if bl_val < 0:
#     282         hrdata = hrdata + abs(bl_val)
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ...
